# %%
import torch 
import numpy as np
import time

# %%
class mBar:
  def __init__(self, arrival_count, count_per_thread=1):
    self.phase = 0
    self.full_arrival_count = arrival_count
    self.current_arrival_count = arrival_count
    self.count_per_thread = count_per_thread

  def arrive(self, count=None):
    if count is None:
      count = self.count_per_thread

    self.current_arrival_count -= count

    if self.current_arrival_count < 0:
      raise RuntimeError("Barrier over-arrival")

    if self.current_arrival_count == 0:
      self._complete()

  def test_wait(self, expected_phase):
    return self.phase != expected_phase

  def wait(self, expected_phase):
    while self.phase == expected_phase:
      pass

  def _complete(self):
    self.phase ^= 1
    self.current_arrival_count = self.full_arrival_count

# %%
num_stages = 4 
empty = [mBar(1) for _ in range(num_stages)]
full = [mBar(1) for _ in range(num_stages)]
